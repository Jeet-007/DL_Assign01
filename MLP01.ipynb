# %%
import numpy as np

X = np.array([[0,0],[0,1],[1,0],[1,1]])

y = [0,1,1,0]

Y =np.array(y).reshape(4,1)

num_examples = len(X) # training set size
nn_input_dim = 2 # input layer dimensionality
nn_output_dim = 1 # output layer dimensionality

epsilon = 0.1 # learning rate for gradient descent

def loss(model):
    W1, b1, W2, b2 = model['W1'], model['b1'], model['W2'], model['b2']
    
    z1 = X.dot(W1) + b1
    a1 = np.tanh(z1)
    z2 = a1.dot(W2) + b2
    #correct_logprobs = -np.log(probs[range(num_examples), y])
    data_loss = np.sum(np.square(np.subtract(z2,Y)))
    return 1./num_examples * data_loss

def predict_output(model, x):
    x_ = np.array([1,0]).reshape(1,2)
    W1, b1, W2, b2 = model['W1'], model['b1'], model['W2'], model['b2']
    # Forward propagation
    z1 = x.dot(W1) + b1
    a1 = np.tanh(z1)
    z2 = a1.dot(W2) + b2
    return z2

def MLP(hidden_dim = 3,epoches=1000, show_loss=False):
    hidden_dim = 3
    W1 = np.random.randn(nn_input_dim, hidden_dim) / np.sqrt(nn_input_dim)
    b1 = np.zeros((1, hidden_dim))
    W2 = np.random.randn(hidden_dim, nn_output_dim) / np.sqrt(hidden_dim)
    b2 = np.zeros((1, nn_output_dim))
 
    model = {}
    
    print('Training Model.....')
    for i in range(0, epoches):
        
        # Forward propagation
        z1 = X.dot(W1) + b1
        a1 = np.tanh(z1)
        z2 = a1.dot(W2) + b2
        
        # Backpropagation
        delta3 = z2
        delta3 = np.subtract(z2,Y)
        
        #delta3[range(num_examples), Y] -= 1
        dW2 = (a1.T).dot(delta3)
        db2 = np.sum(delta3, axis=0, keepdims=True)
        delta2 = delta3.dot(W2.T) * (1 - np.power(a1, 2))
        dW1 = np.dot(X.T, delta2)
        db1 = np.sum(delta2, axis=0, keepdims = True)
        
        # Gradient descent parameter update
        W1 += -epsilon * dW1
        b1 += -epsilon * db1
        W2 += -epsilon * dW2
        b2 += -epsilon * db2
        
        model = { 'W1': W1, 'b1': b1, 'W2': W2, 'b2': b2}
            
        if show_loss and i % 100 == 99:
            print ('Loss after iteration %i: %f' %(i, loss(model)))
    return model


model = MLP(2, show_loss=True)
x = np.array([0,0])
print(predict_output(model,x))
x = np.array([1,0])
print(predict_output(model,x))
x = np.array([0,1])
print(predict_output(model,x))
x = np.array([1,1])
print(predict_output(model,x))
# Out:
# Training Model.....
# Loss after iteration 99: 0.229332
# Loss after iteration 199: 0.056406
# Loss after iteration 299: 0.000209
# Loss after iteration 399: 0.000000
# Loss after iteration 499: 0.000000
# Loss after iteration 599: 0.000000
# Loss after iteration 699: 0.000000
# Loss after iteration 799: 0.000000
# Loss after iteration 899: 0.000000
# Loss after iteration 999: 0.000000
# [[2.3462482e-13]]
# [[1.]]
# [[1.]]
# [[5.49151002e-13]]
